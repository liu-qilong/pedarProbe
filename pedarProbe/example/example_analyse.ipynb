# %%
# add root folder of the project to path
import sys
sys.path.insert(0, '../')

# %%
import pedar

# %%
condition_list = ['fast walking', 'slow walking', 'normal walking']
data = pedar.Trails_Parser("../data/subjects/walking plantar pressure time slot.xlsx", condition_list)
# Out:
# loading 640 data entries
# [====================] 100.0%

# %%
data.sensor_peak(is_export=True, export_folder='../output')

# %%
data.sensor_pti(is_export=True, export_folder='../output')

# %%
import export
hm = export.FootHeatmap(data.subjects['S4'], attr_name='sensor_peak', mask_dir='../data/left_foot_mask.png')
hm.export_foot_heatmap(export_folder='../output')

# %%
hm2 = export.FootHeatmap(data.subjects['S5'], attr_name='sensor_peak')
hm2.export_foot_heatmap(export_folder='../output')
