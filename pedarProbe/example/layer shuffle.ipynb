# %%
# add root folder of the project to path
import sys
sys.path.insert(0, '../')

# %%
import pedar
condition_list = ['fast walking', 'slow walking', 'normal walking']
data = pedar.Trails_Parser("../data/subjects/walking plantar pressure time slot.xlsx", condition_list, max_read_rate=0.1)
# Out:
# loading 640 data entries
# [==                  ] 10.0%

# %%
import copy
from typing import Type, Iterable
from node import Node, Leaf_Node

def node_restructure(node: Type[Node], layers: tuple = ('subject', 'condition', 'time', 'foot', 'stance')) -> Type[Node]:
    # collect all leaf nodes
    def collect_leaf(node: Type[Node], leaf_nodes: list = []) -> Iterable[Leaf_Node]:
        if type(node) is Leaf_Node:
            # when recursion reaches leaf level, print the data frame's shape
            leaf_nodes.append(node)

        else:
            for branch in node.branches():
                leaf_nodes = collect_leaf(branch, leaf_nodes)
        
        return leaf_nodes

    leaf_nodes = collect_leaf(node)

    # prepare layer index dictionary for access data in node.loc
    layer2index = {
        'subject': 1,
        'condition': 2,
        'time': 3,
        'foot': 4,
        'stance': 5,
    }

    # for full layers structure, dismiss the last one
    # since, in this case, the last layer can be automatically identified
    if len(layers) == 5:
        layers = layers[:-1]

    # create root node
    root_node = Node()
    root_node.setup('subjects')

    # parse each leaf node to construct the new node tree
    for leaf in leaf_nodes:
        loc = copy.deepcopy(leaf.loc)
        loc[0] = None
        current_node = root_node

        # add layer to the node tree as instructed
        for layer in layers:
            name = loc[layer2index[layer]]
            loc[layer2index[layer]] = None  # remove the used layer name
            
            branch_node = Node()
            branch_node.setup(name)
            
            current_node.add_branch(branch_node)
            current_node = branch_node
        
        # the unused layers' names are combined as the new leaf node's name
        loc = [str(item) for item in loc if item is not None]
        leaf_name = '-'.join(loc)

        # construct the new leaf node and add it to the node tree
        leaf_node = Leaf_Node()
        leaf_node.setup(name=leaf_name, df=leaf.df, start=leaf.start, end=leaf.end)
        current_node.add_branch(leaf_node)

        print(leaf_node.loc)
    
    return root_node

data_new = node_restructure(data.subjects, layers=('subject', 'time', 'condition'))
# Out:
# ['subjects', 'S4', 1, 'fast walking', 'L-1']
# ['subjects', 'S4', 1, 'fast walking', 'L-2']
# ['subjects', 'S4', 1, 'fast walking', 'L-3']
# ['subjects', 'S4', 1, 'fast walking', 'R-1']
# ['subjects', 'S4', 1, 'fast walking', 'R-2']
# ['subjects', 'S4', 1, 'fast walking', 'R-3']
# ['subjects', 'S4', 2, 'fast walking', 'L-1']
# ['subjects', 'S4', 2, 'fast walking', 'L-2']
# ['subjects', 'S4', 2, 'fast walking', 'L-3']
# ['subjects', 'S4', 2, 'fast walking', 'R-1']
# ['subjects', 'S4', 2, 'fast walking', 'R-2']
# ['subjects', 'S4', 2, 'fast walking', 'R-3']
# ['subjects', 'S4', 3, 'fast walking', 'L-1']
# ['subjects', 'S4', 3, 'fast walking', 'L-2']
# ['subjects', 'S4', 3, 'fast walking', 'L-3']
# ['subjects', 'S4', 3, 'fast walking', 'R-1']
# ['subjects', 'S4', 3, 'fast walking', 'R-2']
# ['subjects', 'S4', 3, 'fast walking', 'R-3']
# ['subjects', 'S4', 1, 'normal walking', 'L-1']
# ['subjects', 'S4', 1, 'normal walking', 'L-2']
# ['subjects', 'S4', 1, 'normal walking', 'L-3']
# ['subjects', 'S4', 1, 'normal walking', 'R-1']
# ['subjects', 'S4', 1, 'normal walking', 'R-2']
# ['subjects', 'S4', 1, 'normal walking', 'R-3']
# ['subjects', 'S4', 2, 'normal walking', 'L-1']
# ['subjects', 'S4', 2, 'normal walking', 'L-2']
# ['subjects', 'S4', 2, 'normal walking', 'L-3']
# ['subjects', 'S4', 2, 'normal walking', 'R-1']
# ['subjects', 'S4', 2, 'normal walking', 'R-2']
# ['subjects', 'S4', 2, 'normal walking', 'R-3']
# ['subjects', 'S4', 3, 'normal walking', 'L-1']
# ['subjects', 'S4', 3, 'normal walking', 'L-2']
# ['subjects', 'S4', 3, 'normal walking', 'L-3']
# ['subjects', 'S4', 3, 'normal walking', 'R-1']
# ['subjects', 'S4', 3, 'normal walking', 'R-2']
# ['subjects', 'S4', 3, 'normal walking', 'R-3']
# ['subjects', 'S4', 1, 'slow walking', 'L-1']
# ['subjects', 'S4', 1, 'slow walking', 'L-2']
# ['subjects', 'S4', 1, 'slow walking', 'L-3']
# ['subjects', 'S4', 1, 'slow walking', 'R-1']
# ['subjects', 'S4', 1, 'slow walking', 'R-2']
# ['subjects', 'S4', 1, 'slow walking', 'R-3']
# ['subjects', 'S4', 2, 'slow walking', 'L-1']
# ['subjects', 'S4', 2, 'slow walking', 'L-2']
# ['subjects', 'S4', 2, 'slow walking', 'L-3']
# ['subjects', 'S4', 2, 'slow walking', 'R-1']
# ['subjects', 'S4', 2, 'slow walking', 'R-2']
# ['subjects', 'S4', 2, 'slow walking', 'R-3']
# ['subjects', 'S4', 3, 'slow walking', 'L-1']
# ['subjects', 'S4', 3, 'slow walking', 'L-2']
# ['subjects', 'S4', 3, 'slow walking', 'L-3']
# ['subjects', 'S4', 3, 'slow walking', 'R-1']
# ['subjects', 'S4', 3, 'slow walking', 'R-2']
# ['subjects', 'S4', 3, 'slow walking', 'R-3']
# ['subjects', 'S5', 1, 'fast walking', 'L-1']
# ['subjects', 'S5', 1, 'fast walking', 'L-2']
# ['subjects', 'S5', 1, 'fast walking', 'L-3']
# ['subjects', 'S5', 1, 'fast walking', 'R-1']
# ['subjects', 'S5', 1, 'fast walking', 'R-2']
# ['subjects', 'S5', 1, 'fast walking', 'R-3']
# ['subjects', 'S5', 2, 'fast walking', 'L-1']
# ['subjects', 'S5', 2, 'fast walking', 'L-2']
# ['subjects', 'S5', 2, 'fast walking', 'L-3']
# ['subjects', 'S5', 2, 'fast walking', 'R-1']
# ['subjects', 'S5', 2, 'fast walking', 'R-2']
# ['subjects', 'S5', 2, 'fast walking', 'R-3']
# ['subjects', 'S5', 3, 'fast walking', 'L-1']
# ['subjects', 'S5', 3, 'fast walking', 'L-2']
# ['subjects', 'S5', 3, 'fast walking', 'L-3']
# ['subjects', 'S5', 3, 'fast walking', 'R-1']
# ['subjects', 'S5', 3, 'fast walking', 'R-2']
# ['subjects', 'S5', 3, 'fast walking', 'R-3']
# ['subjects', 'S5', 1, 'normal walking', 'L-1']
# ['subjects', 'S5', 1, 'normal walking', 'L-2']
# ['subjects', 'S5', 1, 'normal walking', 'L-3']
# ['subjects', 'S5', 1, 'normal walking', 'R-1']
# ['subjects', 'S5', 1, 'normal walking', 'R-2']
# ['subjects', 'S5', 1, 'normal walking', 'R-3']
# ['subjects', 'S5', 2, 'normal walking', 'L-1']
# ['subjects', 'S5', 2, 'normal walking', 'L-2']
# ['subjects', 'S5', 2, 'normal walking', 'L-3']
# ['subjects', 'S5', 2, 'normal walking', 'R-1']
# ['subjects', 'S5', 2, 'normal walking', 'R-2']
# ['subjects', 'S5', 2, 'normal walking', 'R-3']
# ['subjects', 'S5', 3, 'normal walking', 'L-1']
# ['subjects', 'S5', 3, 'normal walking', 'L-2']
# ['subjects', 'S5', 3, 'normal walking', 'L-3']
# ['subjects', 'S5', 3, 'normal walking', 'R-1']
# ['subjects', 'S5', 3, 'normal walking', 'R-2']
# ['subjects', 'S5', 3, 'normal walking', 'R-3']
# ['subjects', 'S5', 1, 'slow walking', 'L-1']
# ['subjects', 'S5', 1, 'slow walking', 'L-2']
# ['subjects', 'S5', 1, 'slow walking', 'L-3']
# ['subjects', 'S5', 1, 'slow walking', 'R-1']
# ['subjects', 'S5', 1, 'slow walking', 'R-2']
# ['subjects', 'S5', 1, 'slow walking', 'R-3']
# ['subjects', 'S5', 2, 'slow walking', 'L-1']
# ['subjects', 'S5', 2, 'slow walking', 'L-2']
# ['subjects', 'S5', 2, 'slow walking', 'L-3']
# ['subjects', 'S5', 2, 'slow walking', 'R-1']
# ['subjects', 'S5', 2, 'slow walking', 'R-2']
# ['subjects', 'S5', 2, 'slow walking', 'R-3']
# ['subjects', 'S5', 3, 'slow walking', 'L-1']
# ['subjects', 'S5', 3, 'slow walking', 'L-2']
# ['subjects', 'S5', 3, 'slow walking', 'L-3']
# ['subjects', 'S5', 3, 'slow walking', 'R-1']
# ['subjects', 'S5', 3, 'slow walking', 'R-2']
# ['subjects', 'S5', 3, 'slow walking', 'R-3']
# ['subjects', 'S6', 1, 'fast walking', 'L-1']
# ['subjects', 'S6', 1, 'fast walking', 'L-2']
# ['subjects', 'S6', 1, 'fast walking', 'L-3']
# ['subjects', 'S6', 1, 'fast walking', 'R-1']
# ['subjects', 'S6', 1, 'fast walking', 'R-2']
# ['subjects', 'S6', 1, 'fast walking', 'R-3']
# ['subjects', 'S6', 2, 'fast walking', 'L-1']
# ['subjects', 'S6', 2, 'fast walking', 'L-2']
# ['subjects', 'S6', 2, 'fast walking', 'L-3']
# ['subjects', 'S6', 2, 'fast walking', 'R-1']
# ['subjects', 'S6', 2, 'fast walking', 'R-2']
# ['subjects', 'S6', 2, 'fast walking', 'R-3']
# ['subjects', 'S6', 3, 'fast walking', 'L-1']
# ['subjects', 'S6', 3, 'fast walking', 'L-2']
# ['subjects', 'S6', 3, 'fast walking', 'L-3']
# ['subjects', 'S6', 3, 'fast walking', 'R-1']
# ['subjects', 'S6', 3, 'fast walking', 'R-2']
# ['subjects', 'S6', 3, 'fast walking', 'R-3']
# ['subjects', 'S6', 1, 'normal walking', 'L-1']
# ['subjects', 'S6', 1, 'normal walking', 'L-2']
# ['subjects', 'S6', 1, 'normal walking', 'L-3']
# ['subjects', 'S6', 1, 'normal walking', 'R-1']
# ['subjects', 'S6', 1, 'normal walking', 'R-2']
# ['subjects', 'S6', 1, 'normal walking', 'R-3']
# ['subjects', 'S6', 2, 'normal walking', 'L-1']
# ['subjects', 'S6', 2, 'normal walking', 'L-2']
# ['subjects', 'S6', 2, 'normal walking', 'L-3']
# ['subjects', 'S6', 2, 'normal walking', 'R-1']
# ['subjects', 'S6', 2, 'normal walking', 'R-2']
# ['subjects', 'S6', 2, 'normal walking', 'R-3']
# ['subjects', 'S6', 3, 'normal walking', 'L-1']
# ['subjects', 'S6', 3, 'normal walking', 'L-2']
# ['subjects', 'S6', 3, 'normal walking', 'L-3']
# ['subjects', 'S6', 3, 'normal walking', 'R-1']
# ['subjects', 'S6', 3, 'normal walking', 'R-2']
# ['subjects', 'S6', 3, 'normal walking', 'R-3']
# ['subjects', 'S6', 1, 'slow walking', 'L-1']
# ['subjects', 'S6', 1, 'slow walking', 'L-2']
# ['subjects', 'S6', 1, 'slow walking', 'L-3']
# ['subjects', 'S6', 1, 'slow walking', 'R-1']
# ['subjects', 'S6', 1, 'slow walking', 'R-2']
# ['subjects', 'S6', 1, 'slow walking', 'R-3']
# ['subjects', 'S6', 2, 'slow walking', 'L-1']
# ['subjects', 'S6', 2, 'slow walking', 'L-2']
# ['subjects', 'S6', 2, 'slow walking', 'L-3']
# ['subjects', 'S6', 2, 'slow walking', 'R-1']
# ['subjects', 'S6', 2, 'slow walking', 'R-2']
# ['subjects', 'S6', 2, 'slow walking', 'R-3']
# ['subjects', 'S6', 3, 'slow walking', 'L-1']
# ['subjects', 'S6', 3, 'slow walking', 'L-2']
# ['subjects', 'S6', 3, 'slow walking', 'L-3']
# ['subjects', 'S6', 3, 'slow walking', 'R-1']
# ['subjects', 'S6', 3, 'slow walking', 'R-2']
# ['subjects', 'S6', 3, 'slow walking', 'R-3']
# ['subjects', 'S7', 1, 'fast walking', 'L-1']
# ['subjects', 'S7', 1, 'fast walking', 'L-2']
# ['subjects', 'S7', 1, 'fast walking', 'L-3']
# ['subjects', 'S7', 1, 'fast walking', 'R-1']
# ['subjects', 'S7', 1, 'fast walking', 'R-2']
# ['subjects', 'S7', 1, 'fast walking', 'R-3']
# ['subjects', 'S7', 2, 'fast walking', 'L-1']
# ['subjects', 'S7', 2, 'fast walking', 'L-2']
# ['subjects', 'S7', 2, 'fast walking', 'L-3']
# ['subjects', 'S7', 2, 'fast walking', 'R-1']
# ['subjects', 'S7', 2, 'fast walking', 'R-2']
# ['subjects', 'S7', 2, 'fast walking', 'R-3']
# ['subjects', 'S7', 3, 'fast walking', 'L-1']
# ['subjects', 'S7', 3, 'fast walking', 'L-2']
# ['subjects', 'S7', 3, 'fast walking', 'L-3']
# ['subjects', 'S7', 3, 'fast walking', 'R-1']
# ['subjects', 'S7', 3, 'fast walking', 'R-2']
# ['subjects', 'S7', 3, 'fast walking', 'R-3']
# ['subjects', 'S7', 1, 'normal walking', 'L-1']
# ['subjects', 'S7', 1, 'normal walking', 'L-2']
# ['subjects', 'S7', 1, 'normal walking', 'L-3']
# ['subjects', 'S7', 1, 'normal walking', 'R-1']
# ['subjects', 'S7', 1, 'normal walking', 'R-2']
# ['subjects', 'S7', 1, 'normal walking', 'R-3']
# ['subjects', 'S7', 2, 'normal walking', 'L-1']
# ['subjects', 'S7', 2, 'normal walking', 'L-2']
# ['subjects', 'S7', 2, 'normal walking', 'L-3']
# ['subjects', 'S7', 3, 'normal walking', 'L-1']
# ['subjects', 'S7', 3, 'normal walking', 'L-2']
# ['subjects', 'S7', 3, 'normal walking', 'L-3']

# %%
data.subjects['S4']['fast walking'][1]['L'].loc
# Out:
# ['subjects', 'S4', 'fast walking', 1, 'L']
