# %%
import pedar

# %%
condition_list = ['fast walking', 'slow walking', 'normal walking']
data = pedar.Trails_Parser("subjects/walking plantar pressure time slot.xlsx", condition_list)
# Out:
# loading 640 data entries
# [=================== ] 100%

# %%
# print all subjects' names
data.subjects.keys()
# Out:
# dict_keys(['S4', 'S5', 'S6', 'S7', 'S9', 'S17', 'S18', 'S19', 'S20', 'S21', 'S22', 'S27', 'S30', 'S34', 'S38', 'S39', 'S40', 'S41', 'S42', 'S46', 'S48', 'S49', 'S51', 'S53', 'S55', 'S56', 'S59', 'S63', 'S64', 'S65', 'S66', 'S67', 'S68', 'S70', 'S72', 'S73'])

# %%
# data slice retrieve
# data.subjects[subject].trails[condition][time][foot][stance]
data.subjects['S65'].trails['fast walking']['2']['R']['1']
# Out:
#        99     100    101    102   103   104    105    106    107    108  ...  \
# 2.08  20.0   85.0  102.5   97.5  67.5   0.0   40.0   40.0   55.0   55.0  ...
# 2.10  55.0  157.5  160.0  152.5  97.5   0.0   60.0  105.0  117.5  105.0  ...
# 2.12  55.0  147.5  157.5  147.5  80.0   0.0  100.0  157.5  160.0  135.0  ...
# 2.14  55.0  140.0  152.5  135.0  67.5   0.0  122.5  187.5  185.0  155.0  ...
# 2.16  62.5  145.0  157.5  127.5  50.0  25.0  160.0  220.0  210.0  172.5  ...
# 2.18  80.0  162.5  170.0  127.5  40.0  47.5  207.5  262.5  245.0  195.0  ...
# 2.20  90.0  172.5  180.0  130.0  40.0  67.5  232.5  290.0  270.0  210.0  ...
# 2.22  90.0  177.5  182.5  132.5  40.0  67.5  235.0  297.5  277.5  215.0  ...
# 2.24  87.5  170.0  177.5  122.5  40.0  67.5  230.0  285.0  267.5  207.5  ...
# 2.26  80.0  155.0  160.0  110.0  35.0  65.0  212.5  255.0  240.0  187.5  ...
# 2.28  67.5  127.5  132.5   87.5  27.5  55.0  182.5  207.5  197.5  157.5  ...
# ...

# %%
# stance start/end time retrieve
# data.subjects[subject].trails[condition][time][foot][stance_(start|end)]
data.subjects['S65'].trails['fast walking']['2']['R']['1_start']
# Out:
# 2.08
